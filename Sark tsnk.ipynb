# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os
for dirname, _, filenames in os.walk('E:\Visual Studio\Analysis\Shark tank.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("E:\Visual Studio\Analysis\Shark tank.csv")
df
# Out:
#      episode_number  pitch_number           brand_name
# 0                 1             1  BluePine Industries  \
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount
# 0                                     Frozen Momos     1                50.0  \
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.shape
# Out:
# (117, 28)

# %%
df.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount
# count      117.000000    117.000000  117.000000          117.000000  \
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation
# count  117.000000     117.000000   117.000000   117.000000      117.000000  \
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
df.describe().T
# Out:
#                        count         mean           std      min     25%
# episode_number         117.0    18.735043     10.070778  1.00000   10.00  \
# pitch_number           117.0    59.000000     33.919021  1.00000   30.00
# deal                   117.0     0.555556      0.499041  0.00000    0.00
# pitcher_ask_amount     117.0   319.854709   2767.842777  0.00101   45.00
# ask_equity             117.0     5.188034      3.892121  0.25000    2.50
# ask_valuation          117.0  3852.462479  11931.601957  0.01000  666.67
# deal_amount            117.0    31.982915     36.687391  0.00000    0.00
# deal_equity            117.0     8.963504     13.106769  0.00000    0.00
# deal_valuation         117.0   467.104872    919.988864  0.00000    0.00
# ashneer_present        117.0     0.837607      0.370397  0.00000    1.00
# anupam_present         117.0     1.000000      0.000000  1.00000    1.00
# aman_present           117.0     0.837607      0.370397  0.00000    1.00
# ...

# %%
df.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['deal'].value_counts()
# Out:
# deal
# 1    65
# 0    52
# Name: count, dtype: int64

# %%
df['aman_deal'].value_counts()
# Out:
# aman_deal
# 0    89
# 1    28
# Name: count, dtype: int64

# %%
df['aman_present'].value_counts()
# Out:
# aman_present
# 1    98
# 0    19
# Name: count, dtype: int64

# %%
df['amount_per_shark'].value_counts()
# Out:
# amount_per_shark
# 0.000000      52
# 25.000000     12
# 50.000000     10
# 20.000000      7
# 10.000000      6
# 40.000000      3
# 75.000000      3
# 100.000000     2
# 37.500000      2
# 15.000000      2
# 33.333333      2
# 65.000000      1
# 17.500000      1
# 80.000000      1
# 0.000253       1
# 16.666667      1
# 1.000000       1
# 13.333333      1
# 22.500000      1
# 0.000017       1
# 35.000000      1
# 8.333333       1
# 30.000000      1
# 28.000000      1
# 70.000000      1
# 12.500000      1
# 5.000000       1
# Name: count, dtype: int64

# %%
aman_present=len(df[df.aman_present==1])
anupam_present=len(df[df.anupam_present==1])
ashneer_present=len(df[df.ashneer_present==1])
ghazal_present=len(df[df.ghazal_present==1])
namita_present=len(df[df.namita_present==1])
peyush_present=len(df[df.peyush_present==1])
vineeta_present=len(df[df.vineeta_present==1])

# %%
fig =plt.figure(figsize=(10,5))
present=[aman_present,anupam_present,ashneer_present,ghazal_present,namita_present,peyush_present,vineeta_present]
names=['Aman','Anupam','Ashneer','Ghazal','Namita','Peyush','Vineeta']
plt.bar(names,present,color='slateblue',width=0.5)
plt.xlabel("Candidate Name")
plt.ylabel("Candidate Present")
plt.title("Candidate Present vs Name")
plt.show()

# %%
plt.pie(present,labels=names,radius=2.5,autopct='%0.1f%%',
        explode=[0.25,0.25,0.25,0.25,0.25,0.25,0.25])
plt.show()

# %%
df['aman_deal'].value_counts()
# Out:
# aman_deal
# 0    89
# 1    28
# Name: count, dtype: int64

# %%
df['deal'].value_counts()
# Out:
# deal
# 1    65
# 0    52
# Name: count, dtype: int64

# %%
df['ashneer_deal'].value_counts()
# Out:
# ashneer_deal
# 0    96
# 1    21
# Name: count, dtype: int64

# %%
df['aman_deal'].value_counts()
# Out:
# aman_deal
# 0    89
# 1    28
# Name: count, dtype: int64

# %%
df['amount_per_shark'].value_counts()
# Out:
# amount_per_shark
# 0.000000      52
# 25.000000     12
# 50.000000     10
# 20.000000      7
# 10.000000      6
# 40.000000      3
# 75.000000      3
# 100.000000     2
# 37.500000      2
# 15.000000      2
# 33.333333      2
# 65.000000      1
# 17.500000      1
# 80.000000      1
# 0.000253       1
# 16.666667      1
# 1.000000       1
# 13.333333      1
# 22.500000      1
# 0.000017       1
# 35.000000      1
# 8.333333       1
# 30.000000      1
# 28.000000      1
# 70.000000      1
# 12.500000      1
# 5.000000       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.countplot(x='total_sharks_invested',data=df)
plt.show()

# %%
df['total_sharks_invested'].value_counts()
# Out:
# total_sharks_invested
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: count, dtype: int64

# %%
num_deal_shark=[df.ashneer_deal.sum(), df.anupam_deal.sum(), df.aman_deal.sum(), df.namita_deal.sum(), df.vineeta_deal.sum(), df.peyush_deal.sum(), df.ghazal_deal.sum()]
all_sharks=["Ashneer", "Anupam", "Aman", "Namita", "Vineeta", "Peyush", "Ghazal"]
figure=px.bar(total_shark, x=all_sharks, y=num_deal_shark,title="Number of deals done by individual shark:")
figure.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 4
#       2 all_sharks=["Ashneer", "Anupam", "Aman", "Namita", "Vineeta", "Peyush", "Ghazal"]
#       3 figure=px.bar(total_shark, x=all_sharks, y=num_deal_shark,title="Number of deals done by individual shark:")
# ----> 4 figure.show()
#
# File c:\Users\GAURAV\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# File c:\Users\GAURAV\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
# ...
