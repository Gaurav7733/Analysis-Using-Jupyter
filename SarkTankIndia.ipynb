# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"Shark Tank India Dataset.csv")

# %%
df
# Out:
#      episode_number  pitch_number           brand_name
# 0                 1             1  BluePine Industries  \
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount
# 0                                     Frozen Momos     1                50.0  \
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount
# count      117.000000    117.000000  117.000000          117.000000  \
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation
# count  117.000000     117.000000   117.000000   117.000000      117.000000  \
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
len(df['episode_number'].unique())
# Out:
# 35

# %%
df['deal'].sum()
(df['deal'] == 1).sum()
# Out:
# 65
# 65

# %%
len(df['idea'].unique())
# Out:
# 117

# %%
print("Deal ratio is",str(round((df['deal'].sum()/len(df['deal']))*100, 2)) + '%')
# Out:
# Deal ratio is 55.56%

# %%
(df['idea'].value_counts() > 1).sum()
# Out:
# 0

# %%
deal_shark = { 'Ashneer': (df['ashneer_deal'] == 1).sum(),
                'Aman': (df['aman_deal'] == 1).sum(),
                'Peyush': (df['peyush_deal'] == 1).sum(),
                'Anupam': (df['anupam_deal'] == 1).sum(),
                'Vineeta': (df['vineeta_deal'] == 1).sum(),
                'Ghazal': (df['ghazal_deal'] == 1).sum(),
                'Namita': (df['namita_deal'] == 1).sum()
               }

# %%
type(deal_shark)
# Out:
# dict

# %%
deal_shark2 = pd.Series(deal_shark)
deal_shark2
# Out:
# Ashneer    21
# Aman       28
# Peyush     27
# Anupam     24
# Vineeta    15
# Ghazal      7
# Namita     22
# dtype: int64

# %%
p = sns.lineplot(data = deal_shark2)
p.set_xlabel("Shark", fontsize = 14)
p.set_ylabel("No. of deals", fontsize = 14)
# Out:
# Text(0.5, 0, 'Shark')
# Text(0, 0.5, 'No. of deals')

# %%
attendance = {
                'Ashneer': (df['ashneer_present']).sum(),
                'Aman': (df['aman_present']).sum(),
                'Peyush': (df['peyush_present']).sum(),
                'Anupam': (df['anupam_present']).sum(),
                'Vineeta': (df['vineeta_present']).sum(),
                'Ghazal': (df['ghazal_present']).sum(),
                'Namita': (df['namita_present']).sum()
           
            }

# %%
attendance = pd.Series(attendance)
attendance
# Out:
# Ashneer     98
# Aman        98
# Peyush      88
# Anupam     117
# Vineeta     66
# Ghazal      26
# Namita     106
# dtype: int64

# %%
p = sns.lineplot(data = attendance)
p.set_xlabel("Shark", fontsize = 14)
p.set_ylabel("No. of shows attended", fontsize = 14)
# Out:
# Text(0.5, 0, 'Shark')
# Text(0, 0.5, 'No. of shows attended')

# %%
attendance
deal_shark2
# Out:
# Ashneer     98
# Aman        98
# Peyush      88
# Anupam     117
# Vineeta     66
# Ghazal      26
# Namita     106
# dtype: int64
# Ashneer    21
# Aman       28
# Peyush     27
# Anupam     24
# Vineeta    15
# Ghazal      7
# Namita     22
# dtype: int64

# %%
deal_shark2/attendance
# Out:
# Ashneer    0.214286
# Aman       0.285714
# Peyush     0.306818
# Anupam     0.205128
# Vineeta    0.227273
# Ghazal     0.269231
# Namita     0.207547
# dtype: float64

# %%
p = sns.lineplot(data=(deal_shark2/attendance)*100)
p.set_xlabel("Shark", fontsize = 14)
p.set_ylabel("Deal OK %", fontsize = 14)
# Out:
# Text(0.5, 0, 'Shark')
# Text(0, 0.5, 'Deal OK %')

# %%
attendance/deal_shark2
# Out:
# Ashneer    4.666667
# Aman       3.500000
# Peyush     3.259259
# Anupam     4.875000
# Vineeta    4.400000
# Ghazal     3.714286
# Namita     4.818182
# dtype: float64

# %%
p = sns.lineplot(data=(attendance/deal_shark2)*10)
p.set_xlabel("Shark", fontsize = 14)
p.set_ylabel("Deal OK %", fontsize = 14)
# Out:
# Text(0.5, 0, 'Shark')
# Text(0, 0.5, 'Deal OK %')

# %%
plt.figure(dpi=1200)

# %%
plt.rcParams['figure.dpi'] = 140
plt.rcParams['savefig.dpi'] = 140

# %%
sns.set(rc={"figure.dpi":100, 'savefig.dpi':300})

# %%
sns.set(rc={"figure.dpi":100, 'savefig.dpi':300})
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# C:\Users\GAURAV\AppData\Local\Temp\ipykernel_5696\2477502134.py:5: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
sns.scatterplot(data=(deal_shark2/attendance)*100)
# Out:
# <Axes: >

# %%
df[df['total_sharks_invested'] > 3 ]['brand_name']
# Out:
# 15               Skippi Pops
# 38           The Yarn Bazaar
# 49     Find Your Kicks India
# 58                   WeSTOCK
# 63                  IN A CAN
# 79       Sunfox Technologies
# 85        Watt Technovations
# 110       Nomad Food Project
# 114            Jain Shikanji
# Name: brand_name, dtype: object

# %%
df[df['total_sharks_invested'] > 3]
# Out:
#      episode_number  pitch_number             brand_name
# 15                6            16            Skippi Pops  \
# 38               13            39        The Yarn Bazaar
# 49               17            50  Find Your Kicks India
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# 79               25            80    Sunfox Technologies
# 85               27            86     Watt Technovations
# 110              34           111     Nomad Food Project
# 114              35           115          Jain Shikanji
#
#                                idea  deal  pitcher_ask_amount  ask_equity
# 15                         Ice-Pops     1            45.00000         5.0  \
# 38                 Yarn-Trading App     1            50.00000         2.0
# 49                   Sneaker Resale     1            50.00000        10.0
# 58   Livestock health monitoring AI     1            50.00000         5.0
# ...

# %%
pitches_per_episode = df.loc[:,['episode_number','pitch_number']]
pitches_per_episode['episode_number'].value_counts()
# Out:
# episode_number
# 18    4
# 30    4
# 17    4
# 16    4
# 22    4
# 23    4
# 27    4
# 31    4
# 32    4
# 33    4
# 34    4
# 19    4
# 29    3
# 28    3
# 20    3
# 26    3
# 25    3
# 24    3
# 21    3
# 1     3
# 2     3
# 15    3
# 14    3
# 13    3
# 12    3
# 11    3
# 10    3
# 9     3
# 8     3
# 7     3
# 6     3
# 5     3
# 4     3
# 3     3
# 35    3
# Name: count, dtype: int64

# %%
pitches_per_episode['episode_number']
# Out:
# 0       1
# 1       1
# 2       1
# 3       2
# 4       2
#        ..
# 112    34
# 113    34
# 114    35
# 115    35
# 116    35
# Name: episode_number, Length: 117, dtype: int64

# %%
sns.histplot(pitches_per_episode['episode_number'],bins=50)
# Out:
# <Axes: xlabel='episode_number', ylabel='Count'>

# %%
temp = df.copy()

# %%
temp.sort_values('total_sharks_invested',ascending=False,inplace=True)
temp
# Out:
#      episode_number  pitch_number             brand_name
# 49               17            50  Find Your Kicks India  \
# 79               25            80    Sunfox Technologies
# 15                6            16            Skippi Pops
# 63               20            64               IN A CAN
# 58               19            59                WeSTOCK
# ..              ...           ...                    ...
# 73               23            74         Guardian Gears
# 74               23            75            Modern Myth
# 77               24            78         Nuskha Kitchen
# 80               25            81                 Alpino
# 116              35           117           Elcare India
#
#                                idea  deal  pitcher_ask_amount  ask_equity
# 49                   Sneaker Resale     1                50.0        10.0  \
# 79              Portable ECG Device     1               100.0         2.0
# ...

# %%
df['total_sharks_invested'].sort_values(ascending=False)[:10]
temp = df.copy()
df.loc[:,['brand_name']]
# Out:
# 49     5
# 79     5
# 15     5
# 63     5
# 58     4
# 114    4
# 110    4
# 38     4
# 85     4
# 29     3
# Name: total_sharks_invested, dtype: int64
#               brand_name
# 0    BluePine Industries
# 1          Booz scooters
# 2    Heart up my Sleeves
# 3             Tagz Foods
# 4         Head and Heart
# ..                   ...
# 112        Green Protein
# 113              On2Cook
# 114        Jain Shikanji
# 115                Woloo
# 116         Elcare India
#
# [117 rows x 1 columns]

# %%
df.columns
money = df.iloc[:,2:11]
money
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')
#               brand_name                                           idea  deal
# 0    BluePine Industries                                   Frozen Momos     1  \
# 1          Booz scooters  Renting e-bike for mobility in private spaces     1
# 2    Heart up my Sleeves                             Detachable Sleeves     1
# 3             Tagz Foods                           Healthy Potato Chips     1
# ...

# %%
money.columns
# Out:
# Index(['brand_name', 'idea', 'deal', 'pitcher_ask_amount', 'ask_equity',
#        'ask_valuation', 'deal_amount', 'deal_equity', 'deal_valuation'],
#       dtype='object')

# %%
money = money.reindex(columns=['brand_name', 'idea', 'deal', 'pitcher_ask_amount', 'deal_amount', 
                               'ask_equity','deal_equity',
                               'ask_valuation','deal_valuation'])
money
# Out:
#               brand_name                                           idea  deal
# 0    BluePine Industries                                   Frozen Momos     1  \
# 1          Booz scooters  Renting e-bike for mobility in private spaces     1
# 2    Heart up my Sleeves                             Detachable Sleeves     1
# 3             Tagz Foods                           Healthy Potato Chips     1
# 4         Head and Heart                       Brain Development Course     0
# ..                   ...                                            ...   ...
# 112        Green Protein                            Plant-Based Protein     0
# 113              On2Cook                         Fastest Cooking Device     0
# 114        Jain Shikanji                                       Lemonade     1
# 115                Woloo                                Washroom Finder     0
# 116         Elcare India                           Carenting for Elders     0
#
# ...

# %%
money = money[money['deal'] == 1]
money
# Out:
#               brand_name                                           idea  deal
# 0    BluePine Industries                                   Frozen Momos     1  \
# 1          Booz scooters  Renting e-bike for mobility in private spaces     1
# 2    Heart up my Sleeves                             Detachable Sleeves     1
# 3             Tagz Foods                           Healthy Potato Chips     1
# 7              Peeschute                           Disposable Urine Bag     1
# ..                   ...                                            ...   ...
# 106        Colour Me Mad                                        Insoles     1
# 108           Tweek Labs                                     Sportswear     1
# 109               Proxgy                                             VR     1
# 110   Nomad Food Project                                     Bacon Jams     1
# 114        Jain Shikanji                                       Lemonade     1
#
# ...

# %%
p = sns.lineplot(data=money['deal_amount'])
p.set_xlabel("Row No.")
p.set_ylabel("Deal Amount")
# Out:
# Text(0.5, 0, 'Row No.')
# Text(0, 0.5, 'Deal Amount')
